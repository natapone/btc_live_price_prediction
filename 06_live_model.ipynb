# %% [markdown]
# #### Init model

# %%
# load BtcTrendPredictor
from btc_trend_predictor import BtcTrendPredictor

predictor = BtcTrendPredictor(predict_period = 1)

# %% [markdown]
# ##### Load trainig data

# %%
df = predictor.get_training_data()

print(df.head(5))
print(df.tail(5))
# Out:
#                      volume_lag71  close_lag71  low_lag71  high_lag71  \
# datetime
# 2021-01-04 00:00:00      0.109600     0.014308   0.009417    0.015110
# 2021-01-04 01:00:00     -0.095185    -0.007322   0.005514   -0.000161
# 2021-01-04 02:00:00     -0.062948     0.002869   0.001030   -0.003335
# 2021-01-04 03:00:00      0.045647    -0.001984  -0.004138    0.000953
# 2021-01-04 04:00:00     -0.042883    -0.001140   0.001885   -0.005434
#
#                      open_lag71  volume_lag70  close_lag70  low_lag70  \
# datetime
# 2021-01-04 00:00:00    0.002472     -0.095185    -0.007322   0.005514
# 2021-01-04 01:00:00    0.014308     -0.062948     0.002869   0.001030
# 2021-01-04 02:00:00   -0.007302      0.045647    -0.001984  -0.004138
# 2021-01-04 03:00:00    0.002848     -0.042883    -0.001140   0.001885
# 2021-01-04 04:00:00   -0.001984     -0.004671    -0.000434  -0.000233
#
#                      high_lag70  open_lag70  ...  close_lag1  low_lag1  \
# ...

# %% [markdown]
# #### Train model

# %%
from btc_trend_predictor import BtcTrendPredictor

predictor = BtcTrendPredictor(predict_period = 1)

model_path =  predictor.train_dl_trend_prediction_model(test_size=0.2, epochs=300, verbose=0)
